# %%
# 1-9 = x
# 10 - 19 = y
# 20 - 29 = x + 10z_1
# 30 - 39 = x + 10z_2
# .
# .
# .
# 90 - 99 = x + 10z_7 
# all of the above = a
# 100 - 199 = a + 100i_1
# 200 - 299 = a + 100i_2
# 300 - 399 = a + 100i_3
# .
# .
# .
# 900 - 999 = a + 100i_9
# 1000 = b
# final formula for finding total letters:
# (Sum from 1 - 9 for a + 100i_n) + b + y

x = 36
y = 70
twenty = len("twenty")
thrity = len("thirty")
forty = len("forty")
fifty = len("fifty")
sixty = len("sixty")
seventy = len("seventy")
eighty = len("eighty")
ninety = len("ninety")

andLen = 3 * 891
hundred = len("hundred") * 900

hundreds = x * 100
# Out:
#   Cell In[1], line 25
#     for i in range(10):
#                        ^
# _IncompleteInputError: incomplete input
