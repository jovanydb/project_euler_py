# %%
def solve8() -> int:
    """Find the greatest product of thirteen adjacent digits in the given number."""
    num_str = (
        "..."
    )

    digits = list(map(int, num_str))
    window_size = 13
    max_product = 0

    for start in range(len(digits) - window_size + 1):
        section = digits[start:start + window_size]

        # Skip if the section contains a zero
        if 0 in section:
            continue

        # Compute product efficiently
        product = 1
        for num in section:
            product *= num

        if product > max_product:
            max_product = product

    return max_product


if __name__ == "__main__":
    print(solve8())
# Out:
# 23514624000
