# %%
def Solve8():
    intList = list(map(int, list('...')))
    dist = 13
    start = 0
    end = len(intList) - dist

    maxSum = 0
    maxSumList = []

    # setting up data structure - list/array
    while start < end + 1:
        section = range(start, start + dist)
        sectionList = [intList[num] for num in section]
        if 0 in sectionList:
            start += 1
            continue
        elif sum(sectionList) >= maxSum:
            maxSum = sum(sectionList)
            maxSumList.append(sectionList) 
        start += 1
        
    # accessing and analyzing the data
    res = 1
    maxProduct = 0
    for lists in maxSumList:
        for num in lists:
            res *= num
        if res > maxProduct:
            maxProduct = res
            res = 1
        else:
            res = 1
    return maxProduct

print(Solve8())
# Out:
# 23514624000

# %%
intList = list(map(int, list('...')))
dist = 12

start = 0
end = len(intList) - dist
res = 1
maxProduct = 0

while start < end + 1:
    print(start)
    section = range(start, start + dist)
    for num in section:
        res *= intList[num]
    print(res)
    
    if res > maxProduct:
            maxProduct = res
    
    res = 1
    start += 1

print(maxProduct)
