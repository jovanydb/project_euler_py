# %%
def solve16(n: int) -> int:
    """
    Return the sum of the digits of 2^n.
    """
    return sum(int(d) for d in str(2**n))


if __name__ == "__main__":
    print(solve16(1000))
# Out:
# 1366
